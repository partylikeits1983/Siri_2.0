# %% [markdown]
# ## Parsing WhatsApp and Telegram messages

# %% [markdown]
# 1) Add WhatsApp messages to chats folder

# %%
# concat all files in chats directory [WhatsApp]

import os

path = 'raw_chats/whatsapp_raw'
files = os.listdir(path)
with open("raw_chats/output_file.txt", "w") as fo: 
    for infile in files:
        with open(os.path.join(path, infile)) as fin:
            for line in fin:
                fo.write(line)

# %%
# concat certain files in directory [WhatsApp]
# only if you want to use specific chats from WhatsApp

filenames = ['1.txt', '2.txt', '3.txt', '4.txt', "5.txt" ]

path = 'raw_chats/whatsapp_raw'

with open("raw_chats/output_file.txt", "w") as outfile:

    for filename in filenames:

        with open(path + filename) as infile:

            contents = infile.read()

            outfile.write(contents)

# %%
# To clean and convert a whatsapp txt file export to a CSV file

import pandas as pd

# read file by lines
file_path = "raw_chats/output_file.txt"
f = open(file_path, 'r')
data = f.readlines()
f.close()

# sanity stats
print('num lines: %s' %(len(data)))

# parse text and create list of lists structure
# remove first whatsapp info message
dataset = data[1:]
cleaned_data = []
for line in dataset:
    # grab the info and cut it out
    date = line.split(",")[0]
    line2 = line[len(date):]
    time = line2.split("-")[0][2:]
    line3 = line2[len(time):]
    name = line3.split(":")[0][4:]
    line4 = line3[len(name):]
    message = line4[6:-1] # strip newline charactor

    #print(date, time, name, message)
    cleaned_data.append([date, time, name, message])

    
# Create the DataFrame 
df = pd.DataFrame(cleaned_data, columns = ['Date', 'Time', 'Name', 'Message']) 

# check formatting 
if 0:
    print(df.head())
    print(df.tail())


# Save it
df.to_csv('raw_chats/converted_messages.csv', index=False)
# Out:
# num lines: 10

# %%
df = pd.read_csv ('raw_chats/converted_messages.csv')
print(df)
# Out:
#       Date    Time                Name  \
# 0  8/22/21  19:54   Alexander John Lee
# 1  9/18/21  07:48   Alexander John Lee
# 2  9/18/21  07:48   Alexander John Lee
# 3  9/18/21  09:57             Vladimir
# 4  9/19/21  22:11   Alexander John Lee
# 5  9/19/21  22:13   Alexander John Lee
# 6  9/19/21  22:19             Vladimir
# 7  9/19/21  22:20             Vladimir
# 8  9/19/21  22:34   Alexander John Lee
#
#                                              Message
# 0                                                Hey
# 1                                    <Media omitted>
# 2                          check out this bot I made
# 3                                         impressive
# 4  I have a legal question: could an agreement be...
# 5  I don't think it can be because an internation...
# 6                                  Missed video call
# 7       I have some ideas. Call me when you’re free.
# 8                               Let's talk tomorrow.

# %%
df.drop(['Date', 'Time'], axis=1, inplace = True)

# %%
df.columns = ['name', 'line']

# %%
df
# Out:
#                  name                                               line
# 0  Alexander John Lee                                                Hey
# 1  Alexander John Lee                                    <Media omitted>
# 2  Alexander John Lee                          check out this bot I made
# 3            Vladimir                                         impressive
# 4  Alexander John Lee  I have a legal question: could an agreement be...
# 5  Alexander John Lee  I don't think it can be because an internation...
# 6            Vladimir                                  Missed video call
# 7            Vladimir       I have some ideas. Call me when you’re free.
# 8  Alexander John Lee                               Let's talk tomorrow.

# %%
df.to_csv("raw_chats/messages.csv", index = False)

# %%
# remove empty lines (if any exist)
import csv


with open('raw_chats/messages.csv') as in_file:
    with open('raw_chats/messages1.csv', 'w') as out_file:
        writer = csv.writer(out_file)
        for row in csv.reader(in_file):
            if any(row):
                writer.writerow(row)

# %% [markdown]
# ## cleaning WhatsApp messages - remove "Media ommitted" lines

# %%
# delete anyline that has this phrase in it: <Media ommitted> (this message was an image)
# We open the source file and get its lines
with open('raw_chats/messages1.csv', 'r') as inp:
    lines = inp.readlines()

# We open the target file in write-mode
with open('csv/parsed/wa-messages.csv', 'w') as out:
    # We go line by line writing in the target file
    # if the original line does not include the
    # strings 'py-board' or 'coffee'
    for line in lines:
        if not '<Media omitted>' in line and not '/' in line:
            out.write(line)

# %% [markdown]
# ## 2) Add result.json to the raw_chats/telegram_raw directory

# %%
# !python3 telegramParser.py raw_chats/telegram_raw/result.json dump.csv
# Out:
# Parsing Completed

# %%
import pandas as pd
import glob

path = "csv" 
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

df = pd.concat(li, axis=0, ignore_index=True)

# %%
df = df.filter(['sender', 'msg_content'])
df.columns = ['name', 'line']

# %%
df.to_csv("csv/parsed/telegram-messages.csv", index = False)

# %%
df
# Out:
#              name                                               line
# 0   Alexander Lee                                         Hey Vlad!!
# 1  Vladimir Putin                                    Hello Alexander
# 2   Alexander Lee                                     How's Moscow?!
# 3  Vladimir Putin                       It's nice this time of year.
# 4  Vladimir Putin                                          very nice
# 5  Vladimir Putin                                       How are you?
# 6   Alexander Lee  I'm doing well. Looking forward to being back ...
# 7  Vladimir Putin        Looking forward to see you again my friend.
# 8   Alexander Lee                                Thanks man, you too

# %%
import pandas as pd
import glob

path = "csv/parsed" 
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

df = pd.concat(li, axis=0, ignore_index=True)

# %%
df
# Out:
#                   name                                               line
# 0   Alexander John Lee                                                Hey
# 1   Alexander John Lee                          check out this bot I made
# 2             Vladimir                                         impressive
# 3   Alexander John Lee  I have a legal question: could an agreement be...
# 4   Alexander John Lee  I don't think it can be because an internation...
# 5             Vladimir                                  Missed video call
# 6             Vladimir       I have some ideas. Call me when you’re free.
# 7   Alexander John Lee                               Let's talk tomorrow.
# 8        Alexander Lee                                                Hey
# 9        Alexander Lee                          check out this bot I made
# 10            Vladimir                                         impressive
# 11       Alexander Lee  I have a legal question: could an agreement be...
# 12       Alexander Lee  I don't think it can be because an internation...
# 13            Vladimir                                  Missed video call
# 14            Vladimir       I have some ideas. Call me when you’re free.
# 15       Alexander Lee                               Let's talk tomorrow.
# 16       Alexander Lee                                         Hey Vlad!!
# 17      Vladimir Putin                                    Hello Alexander
# 18       Alexander Lee                                     How's Moscow?!
# 19      Vladimir Putin                       It's nice this time of year.
# 20      Vladimir Putin                                          very nice
# 21      Vladimir Putin                                       How are you?
# 22       Alexander Lee  I'm doing well. Looking forward to being back ...
# 23      Vladimir Putin        Looking forward to see you again my friend.
# 24       Alexander Lee                                Thanks man, you too
# 25       Alexander Lee                                         Hey Vlad!!
# 26      Vladimir Putin                                    Hello Alexander
# 27       Alexander Lee                                     How's Moscow?!
# 28      Vladimir Putin                       It's nice this time of year.
# 29      Vladimir Putin                                          very nice
# 30      Vladimir Putin                                       How are you?
# 31       Alexander Lee  I'm doing well. Looking forward to being back ...
# 32      Vladimir Putin        Looking forward to see you again my friend.
# 33       Alexander Lee                                Thanks man, you too
# 34       Alexander Lee                                                Hey
# 35       Alexander Lee                          check out this bot I made
# 36            Vladimir                                         impressive
# 37       Alexander Lee  I have a legal question: could an agreement be...
# 38       Alexander Lee  I don't think it can be because an internation...
# 39            Vladimir                                  Missed video call
# 40            Vladimir       I have some ideas. Call me when you’re free.
# 41       Alexander Lee                               Let's talk tomorrow.
# 42       Alexander Lee                                         Hey Vlad!!
# 43      Vladimir Putin                                    Hello Alexander
# 44       Alexander Lee                                     How's Moscow?!
# 45      Vladimir Putin                       It's nice this time of year.
# 46      Vladimir Putin                                          very nice
# 47      Vladimir Putin                                       How are you?
# 48       Alexander Lee  I'm doing well. Looking forward to being back ...
# 49      Vladimir Putin        Looking forward to see you again my friend.
# 50       Alexander Lee                                Thanks man, you too

# %%
df.to_csv("csv/parsed/all-messages.csv", index = False)

# %%
with open('csv/parsed/all-messages.csv', 'r') as inp:
    lines = inp.readlines()

# We open the target file in write-mode
with open('csv/parsed/all-messages1.csv', 'w') as out:
    # We go line by line writing in the target file
    # if the original line does not include the
    # strings 'py-board' or 'coffee'
    for line in lines:
        if not '(File not included. Change data exporting settings to download.)' in line and not '/' in line:
            out.write(line)

# %%
df = pd.read_csv('csv/parsed/all-messages1.csv')
df.to_csv("csv/parsed/all-messages.csv", index = False)

# %%
with open('csv/parsed/all-messages.csv', 'r') as inp:
    lines = inp.readlines()

# We open the target file in write-mode
with open('csv/parsed/all-messages1.csv', 'w') as out:
    # We go line by line writing in the target file
    # if the original line does not include the
    # strings 'py-board' or 'coffee'
    for line in lines:
        if not 'Messages and calls are end-to-end encrypted' in line and not '/' in line:
            out.write(line)

# %% [markdown]
# ## Removing Emojis (this is optional)

# %%
import re

with open('csv/parsed/all-messages.csv', 'r') as file :
  filedata = file.read()

# Replace the target string
filedata = filedata.replace('+1 (865) 804-1446', 'Mom')
filedata = filedata.replace('Alexander John Lee', 'Alexander Lee')


emoji_pattern = re.compile("["
   "\U0001F600-\U0001F64F"
   "\U0001F300-\U0001F5FF"
   "\U0001F680-\U0001F6FF"
   "\U0001F1E0-\U0001F1FF"
   # flags(iOS)
   "]+", flags = re.UNICODE)

filedata = emoji_pattern.sub('haha', filedata)

# Write the file out again
with open('csv/parsed/all-messages.csv', 'w') as file:
  file.write(filedata)

# %% [markdown]
# ## Removing lines with less than 6 characters (formatting)

# %%
text = ''

with open('csv/parsed/all-messages.csv', 'r') as f:
    strip = str.rstrip
    text += '\n'.join([line for line in f if len(strip(line, '\n')) >= 6]).rstrip('\n')

with open('csv/parsed/all-messages1.csv', 'w') as file:
    file.write(text)

# %% [markdown]
# ## Removing empty lines

# %%
with open('csv/parsed/all-messages1.csv') as in_file:
    with open('csv/parsed/all-messages.csv', 'w') as out_file:
        writer = csv.writer(out_file)
        for row in csv.reader(in_file):
            if any(row):
                writer.writerow(row)

# %% [markdown]
# ## Convert csv to txt

# %%
import csv
csv_file = "csv/parsed/all-messages.csv"
txt_file = "csv/parsed/all-messages.txt"

with open(txt_file, "w") as my_output_file:
   with open(csv_file, "r") as my_input_file: [my_output_file.write(": ".join(row) + '\n') for row in csv.reader(my_input_file)]
my_output_file.close()

# %%
# @dev

# 1)
# clean up txt file: change phone numbers to names
# make telegram and whatsapp usernames the same 

# 2) 
# remove emojis
# remove foreign languages or translate text.

# %%
# translate foreign language to English if you are bi or trilingual

# %%
import re
import pandas as pd

pattern = r'([a-zA-Zа-яА-Я\s]+):(.+)'

data = {
    'name': [],
    'line': []
}

with open('csv/parsed/all-messages.txt', 'rt') as file:
    for line in file.readlines():
        match = re.findall(pattern,line)
        if match:
            name, line = match[0]
            data['name'].append(name)
            data['line'].append(line)
            
df = pd.DataFrame(data)

# %%
df
# Out:
#               name                                               line
# 0             name                                               line
# 1    Alexander Lee                                                Hey
# 2    Alexander Lee                          check out this bot I made
# 3         Vladimir                                         impressive
# 4    Alexander Lee   I have a legal question: could an agreement b...
# 5    Alexander Lee   I don't think it can be because an internatio...
# 6         Vladimir                                  Missed video call
# 7         Vladimir       I have some ideas. Call me when you’re free.
# 8    Alexander Lee                               Let's talk tomorrow.
# 9    Alexander Lee                                                Hey
# 10   Alexander Lee                          check out this bot I made
# 11        Vladimir                                         impressive
# 12   Alexander Lee   I have a legal question: could an agreement b...
# 13   Alexander Lee   I don't think it can be because an internatio...
# 14        Vladimir                                  Missed video call
# 15        Vladimir       I have some ideas. Call me when you’re free.
# 16   Alexander Lee                               Let's talk tomorrow.
# 17   Alexander Lee                                         Hey Vlad!!
# 18  Vladimir Putin                                    Hello Alexander
# 19   Alexander Lee                                     How's Moscow?!
# 20  Vladimir Putin                       It's nice this time of year.
# 21  Vladimir Putin                                          very nice
# 22  Vladimir Putin                                       How are you?
# 23   Alexander Lee   I'm doing well. Looking forward to being back...
# 24  Vladimir Putin        Looking forward to see you again my friend.
# 25   Alexander Lee                                Thanks man, you too
# 26   Alexander Lee                                         Hey Vlad!!
# 27  Vladimir Putin                                    Hello Alexander
# 28   Alexander Lee                                     How's Moscow?!
# 29  Vladimir Putin                       It's nice this time of year.
# 30  Vladimir Putin                                          very nice
# 31  Vladimir Putin                                       How are you?
# 32   Alexander Lee   I'm doing well. Looking forward to being back...
# 33  Vladimir Putin        Looking forward to see you again my friend.
# 34   Alexander Lee                                Thanks man, you too
# 35   Alexander Lee                                                Hey
# 36   Alexander Lee                          check out this bot I made
# 37        Vladimir                                         impressive
# 38   Alexander Lee   I have a legal question: could an agreement b...
# 39   Alexander Lee   I don't think it can be because an internatio...
# 40        Vladimir                                  Missed video call
# 41        Vladimir       I have some ideas. Call me when you’re free.
# 42   Alexander Lee                               Let's talk tomorrow.
# 43   Alexander Lee                                         Hey Vlad!!
# 44  Vladimir Putin                                    Hello Alexander
# 45   Alexander Lee                                     How's Moscow?!
# 46  Vladimir Putin                       It's nice this time of year.
# 47  Vladimir Putin                                          very nice
# 48  Vladimir Putin                                       How are you?
# 49   Alexander Lee   I'm doing well. Looking forward to being back...
# 50  Vladimir Putin        Looking forward to see you again my friend.
# 51   Alexander Lee                                Thanks man, you too

# %%
df.to_csv("all-messages.csv", index = False)

# %%
# convert csv to txt
import csv
csv_file = "all-messages.csv"
txt_file = "all-messages.txt"

with open(txt_file, "w") as my_output_file:
   with open(csv_file, "r") as my_input_file: [my_output_file.write(": ".join(row) + '\n') for row in csv.reader(my_input_file)]
my_output_file.close()

# %% [markdown]
# ## Translate messages that are not in English

# %%
# !pip install deep_translator
# Out:
# /usr/lib/python3/dist-packages/secretstorage/dhcrypto.py:15: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /usr/lib/python3/dist-packages/secretstorage/util.py:19: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: deep_translator in /home/ubuntu/.local/lib/python3.8/site-packages (1.6.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /home/ubuntu/.local/lib/python3.8/site-packages (from deep_translator) (4.10.0)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from deep_translator) (2.26.0)
# Requirement already satisfied: click<9.0.0,>=8.0.1 in /home/ubuntu/.local/lib/python3.8/site-packages (from deep_translator) (8.0.3)
# Requirement already satisfied: soupsieve>1.2 in /home/ubuntu/.local/lib/python3.8/site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep_translator) (2.2.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (2019.11.28)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from requests<3.0.0,>=2.23.0->deep_translator) (2.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ubuntu/.local/lib/python3.8/site-packages (from requests<3.0.0,>=2.23.0->deep_translator) (1.26.7)
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
from tqdm import tqdm
from deep_translator import GoogleTranslator

def isEnglish(s):
    return s.isascii()

file = open('all-messages.txt', 'r')
lines = file.readlines()

with open('all-messages1.txt', 'a') as f:
     
    for line in tqdm(lines):
        
        result = isEnglish(line)
        
        if result == False:        
            translated = GoogleTranslator(source='auto', target='en').translate(line)
            f.write(translated + '\n') 
        else:
            f.write(line + '\n')
# Out:
# 100%|██████████| 53/53 [00:00<00:00, 113.69it/s]

# %% [markdown]
# # Formating

# %%
import re
import pandas as pd

pattern = r'([a-zA-Z\s]+):(.+)'

data = {
    'name': [],
    'line': []
}

with open('all-messages1.txt', 'rt') as file:
    for line in file.readlines():
        match = re.findall(pattern,line)
        if match:
            name, line = match[0]
            data['name'].append(name)
            data['line'].append(line)
            
df = pd.DataFrame(data)

df
# Out:
#               name                                               line
# 0             name                                               line
# 1             name                                               line
# 2    Alexander Lee                                                Hey
# 3    Alexander Lee                          check out this bot I made
# 4         Vladimir                                         impressive
# 5    Alexander Lee    I have a legal question: could an agreement ...
# 6    Alexander Lee    I don't think it can be because an internati...
# 7         Vladimir                                  Missed video call
# 8         Vladimir       I have some ideas. Call me when you’re free.
# 9    Alexander Lee                               Let's talk tomorrow.
# 10   Alexander Lee                                                Hey
# 11   Alexander Lee                          check out this bot I made
# 12        Vladimir                                         impressive
# 13   Alexander Lee    I have a legal question: could an agreement ...
# 14   Alexander Lee    I don't think it can be because an internati...
# 15        Vladimir                                  Missed video call
# 16        Vladimir       I have some ideas. Call me when you’re free.
# 17   Alexander Lee                               Let's talk tomorrow.
# 18   Alexander Lee                                         Hey Vlad!!
# 19  Vladimir Putin                                    Hello Alexander
# 20   Alexander Lee                                     How's Moscow?!
# 21  Vladimir Putin                       It's nice this time of year.
# 22  Vladimir Putin                                          very nice
# 23  Vladimir Putin                                       How are you?
# 24   Alexander Lee    I'm doing well. Looking forward to being bac...
# 25  Vladimir Putin        Looking forward to see you again my friend.
# 26   Alexander Lee                                Thanks man, you too
# 27   Alexander Lee                                         Hey Vlad!!
# 28  Vladimir Putin                                    Hello Alexander
# 29   Alexander Lee                                     How's Moscow?!
# 30  Vladimir Putin                       It's nice this time of year.
# 31  Vladimir Putin                                          very nice
# 32  Vladimir Putin                                       How are you?
# 33   Alexander Lee    I'm doing well. Looking forward to being bac...
# 34  Vladimir Putin        Looking forward to see you again my friend.
# 35   Alexander Lee                                Thanks man, you too
# 36   Alexander Lee                                                Hey
# 37   Alexander Lee                          check out this bot I made
# 38        Vladimir                                         impressive
# 39   Alexander Lee    I have a legal question: could an agreement ...
# 40   Alexander Lee    I don't think it can be because an internati...
# 41        Vladimir                                  Missed video call
# 42        Vladimir       I have some ideas. Call me when you’re free.
# 43   Alexander Lee                               Let's talk tomorrow.
# 44   Alexander Lee                                         Hey Vlad!!
# 45  Vladimir Putin                                    Hello Alexander
# 46   Alexander Lee                                     How's Moscow?!
# 47  Vladimir Putin                       It's nice this time of year.
# 48  Vladimir Putin                                          very nice
# 49  Vladimir Putin                                       How are you?
# 50   Alexander Lee    I'm doing well. Looking forward to being bac...
# 51  Vladimir Putin        Looking forward to see you again my friend.
# 52   Alexander Lee                                Thanks man, you too

# %%
df.to_csv("all-messages.csv", index = False)

# %%
# !rm all-messages.txt
# !rm all-messages1.txt

# %% [markdown]
# ## All done! Now you can train your model!
# Open trainModel.ipynb in Google Colab and upload all-messages.csv
